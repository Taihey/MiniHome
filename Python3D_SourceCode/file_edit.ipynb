# %%
import pandas as pd

# %%
df_food_sub = pd.read_pickle('df_food_sub.pickle')
df_food_sub
# Out:
#                            食材      量   カロリー  タンパク質    脂質   炭水化物  食塩相当量
# 0                       白米[合]    1.0  520.0    8.0   0.8  124.0  0.000
# 1                      鶏胸肉[g]  100.0  108.0   22.3   1.0    0.0  0.100
# 2           豚野菜うま塩炒め(中央食堂)[個]    1.0  188.0   12.2  10.3   11.3  1.200
# 3             ホッケ塩焼き(中央食堂)[個]    1.0  146.0   17.9   7.9    0.8  1.700
# 4        薩摩ハーブ鶏のレバー煮(中央食堂)[個]    1.0   81.0    9.4   1.3    8.1  1.300
# 5      ライス200g(中サイズ)(中央食堂)[個]    1.0  340.0    6.0   0.0   74.0  0.000
# 6       コーンフレーク シュガー(coop)[g]   40.0  160.0    2.0   0.3   36.1  0.500
# 7         ヨーグルト ナチュレ恵 脂肪ゼロ[g]  100.0   46.0    3.9   0.0    7.0  0.140
# 8        オレンジマーマレード(Kanpy)[g]   20.0   50.0    0.0   0.0   12.6  0.002
# 9         おかめ納豆極小粒(たれ付き)[パック]    1.0  100.0    8.4   4.9    7.4  0.700
# 10  シーチキンマイルド オイル不使用(coop)[缶]    1.0   50.0   12.2   0.1    0.1  0.700
# 11         ブルガリアヨーグルト 脂肪ゼロ[g]  100.0   41.0    4.1   0.0    6.1  0.140
# 12    いつものおみそ汁 シジミ(アマノフーズ)[個]    1.0   41.0    4.1   0.0    6.1  0.140

# %%
df_food_sub = df_food_sub.drop(index = 12)
df_food_sub
# Out:
#                            食材      量   カロリー  タンパク質    脂質   炭水化物  食塩相当量
# 0                       白米[合]    1.0  520.0    8.0   0.8  124.0  0.000
# 1                      鶏胸肉[g]  100.0  108.0   22.3   1.0    0.0  0.100
# 2           豚野菜うま塩炒め(中央食堂)[個]    1.0  188.0   12.2  10.3   11.3  1.200
# 3             ホッケ塩焼き(中央食堂)[個]    1.0  146.0   17.9   7.9    0.8  1.700
# 4        薩摩ハーブ鶏のレバー煮(中央食堂)[個]    1.0   81.0    9.4   1.3    8.1  1.300
# 5      ライス200g(中サイズ)(中央食堂)[個]    1.0  340.0    6.0   0.0   74.0  0.000
# 6       コーンフレーク シュガー(coop)[g]   40.0  160.0    2.0   0.3   36.1  0.500
# 7         ヨーグルト ナチュレ恵 脂肪ゼロ[g]  100.0   46.0    3.9   0.0    7.0  0.140
# 8        オレンジマーマレード(Kanpy)[g]   20.0   50.0    0.0   0.0   12.6  0.002
# 9         おかめ納豆極小粒(たれ付き)[パック]    1.0  100.0    8.4   4.9    7.4  0.700
# 10  シーチキンマイルド オイル不使用(coop)[缶]    1.0   50.0   12.2   0.1    0.1  0.700
# 11         ブルガリアヨーグルト 脂肪ゼロ[g]  100.0   41.0    4.1   0.0    6.1  0.140

# %%
df_food_sub.to_pickle('df_food_sub.pickle')

# %%
#食事した記録の表を読みこむ
#これとは別に、摂取カロリーのひょうも読み込む必要がある
df_eat_sub = pd.read_pickle('df_eat.pickle')
df_eat_sub
# Out:
#              日付     時     分                            食品  量(g, 合, 個)
# 0    2023-05-15  14.0  13.0                   鶏胸肉(皮なし)[g]       100.0
# 1    2023-05-19   9.0   0.0                         白米[合]         0.5
# 2    2023-05-19   9.0   0.0     シーチキンマイルド オイル不使用(coop)[缶]         1.0
# 3    2023-05-19   9.0   0.0           おかめ納豆極小粒(たれ付き)[パック]         1.0
# 4    2023-05-19  11.0  30.0               ホッケ塩焼き(中央食堂)[個]         1.0
# ..          ...   ...   ...                           ...         ...
# 193  2023-05-27  23.0  15.0              コーンフレーク(プレーン)[g]        33.0
# 194  2023-05-27  23.0  15.0  ピスタチオスプレッド(Made in Italy)[g]        10.0
# 195  2023-05-15  15.0   9.0       いつものおみそ汁 しじみ(アマノフーズ)[個]         3.0
# 197  2023-12-15    18    50              コーンフレーク(プレーン)[g]       566.0
# 198  2023-12-15    20    57       いつものお味噌汁 カニ汁(アマノフーズ)[個]         4.0
#
# [198 rows x 5 columns]

# %%
df_eat = df_eat_sub.drop(198)
df_eat
# Out:
#              日付     時     分                            食品  量(g, 合, 個)
# 0    2023-05-15  14.0  13.0                   鶏胸肉(皮なし)[g]       100.0
# 1    2023-05-19   9.0   0.0                         白米[合]         0.5
# 2    2023-05-19   9.0   0.0     シーチキンマイルド オイル不使用(coop)[缶]         1.0
# 3    2023-05-19   9.0   0.0           おかめ納豆極小粒(たれ付き)[パック]         1.0
# 4    2023-05-19  11.0  30.0               ホッケ塩焼き(中央食堂)[個]         1.0
# ..          ...   ...   ...                           ...         ...
# 192  2023-05-27  23.0  15.0           ヨーグルト ナチュレ恵 脂肪ゼロ[g]       100.0
# 193  2023-05-27  23.0  15.0              コーンフレーク(プレーン)[g]        33.0
# 194  2023-05-27  23.0  15.0  ピスタチオスプレッド(Made in Italy)[g]        10.0
# 195  2023-05-15  15.0   9.0       いつものおみそ汁 しじみ(アマノフーズ)[個]         3.0
# 197  2023-12-15    18    50              コーンフレーク(プレーン)[g]       566.0
#
# [197 rows x 5 columns]

# %%
df_eat.loc[195]
# Out:
# 日付                         2023-05-15
# 時                                15.0
# 分                                 9.0
# 食品            いつものおみそ汁 しじみ(アマノフーズ)[個]
# 量(g, 合, 個)                        3.0
# Name: 195, dtype: object

# %%
df_eat_sub.to_pickle('df_eat_sub.pickle')

# %%
#摂取カロリーの表を読みこむ
df_eatcal_sub = pd.read_pickle('df_eatcal.pickle')
df_eatcal_sub
# Out:
#       カロリー  タンパク質    脂質   炭水化物   食塩相当量
# 0    108.0  22.30  1.00   0.00  0.1000
# 1    260.0   4.00  0.40  62.00  0.0000
# 2     50.0  12.20  0.10   0.10  0.7000
# 3    100.0   8.40  4.90   7.40  0.7000
# 4    146.0  17.90  7.90   0.80  1.7000
# ..     ...    ...   ...    ...     ...
# 192   46.0   3.90  0.00   7.00  0.1400
# 193  123.8   2.14  0.25  28.54  0.5775
# 194   60.6   0.71  4.24   4.72  0.0080
# 195   75.0   4.80  1.53  10.50  4.5000
# 197  124.0  10.00  2.72  14.80  6.8000
#
# [197 rows x 5 columns]

# %%
df_eatcal = df_eatcal_sub.drop(index=196)
df_eatcal
# Out:
#       カロリー  タンパク質    脂質   炭水化物   食塩相当量
# 0    108.0  22.30  1.00   0.00  0.1000
# 1    260.0   4.00  0.40  62.00  0.0000
# 2     50.0  12.20  0.10   0.10  0.7000
# 3    100.0   8.40  4.90   7.40  0.7000
# 4    146.0  17.90  7.90   0.80  1.7000
# ..     ...    ...   ...    ...     ...
# 192   46.0   3.90  0.00   7.00  0.1400
# 193  123.8   2.14  0.25  28.54  0.5775
# 194   60.6   0.71  4.24   4.72  0.0080
# 195   75.0   4.80  1.53  10.50  4.5000
# 197  200.0  16.80  9.80  14.80  1.4000
#
# [197 rows x 5 columns]

# %%
df_eatcal.to_pickle('df_eatcal.pickle')

# %%
df_eat.to_pickle('df_eat.pickle')
